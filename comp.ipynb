# %%
import numpy as np
import pandas as pd
import nltk
from nltk.stem import PorterStemmer
from nltk.util import ngrams
import re

train_data_path = 'train.tsv'
test_data_path = 'valid.tsv'
output_path = 'output.txt'
stop_path = 'stopwords.txt'

# %%
train_df= pd.read_csv(train_data_path,header=None,sep='\t',quoting=3)
train_x= train_df[2]
train_y= train_df[1]

credit_scores = train_df[[8, 9, 10, 11, 12]].apply(pd.to_numeric, errors='coerce').values
row_sums = credit_scores.sum(axis=1, keepdims=True)
credit_scores_normalized = np.where(row_sums > 0, credit_scores / row_sums, 0)
# Out:
# /var/folders/3x/n0vzxnz14dv3szr81wc5q8pm0000gn/T/ipykernel_23079/2900694295.py:7: RuntimeWarning: invalid value encountered in divide
#   credit_scores_normalized = np.where(row_sums > 0, credit_scores / row_sums, 0)

# %%
label_to_index = {'pants-fire': 0, 'false': 1, 'barely-true': 2, 'half-true': 3, 'mostly-true': 4, 'true': 5}
index_to_label = {v: k for k, v in label_to_index.items()}
Y = np.array([label_to_index[label] for label in train_y])

# %%
import numpy as np

def softmax(logits):
    exp_scores = np.exp(logits - np.max(logits, axis=1, keepdims=True)) 
    return exp_scores / np.sum(exp_scores, axis=1, keepdims=True)

def compute_loss(probs, y_true, num_classes):
    y_true_one_hot = np.eye(num_classes)[y_true] 
    log_probs = -np.log(probs[range(len(y_true)), y_true])  
    loss = np.sum(log_probs) / len(y_true)
    return loss

class LogisticRegression:
    def __init__(self, num_features, num_classes, lr=0.01):
        self.weights = np.random.randn(num_features, num_classes) * 0.01  
        self.bias = np.zeros((1, num_classes)) 
        self.lr = lr 
    
    def fit(self, X, y, num_classes, epochs):
        num_samples, num_features = X.shape
    
        for epoch in range(epochs):
            logits = np.dot(X, self.weights) + self.bias 
            probs = softmax(logits)  
            loss = compute_loss(probs, y, num_classes)

            y_true_one_hot = np.eye(num_classes)[y]
            dL_dlogits = probs - y_true_one_hot  
            dL_dw = np.dot(X.T, dL_dlogits) / num_samples 
            dL_db = np.sum(dL_dlogits, axis=0, keepdims=True) / num_samples  
            self.weights -= self.lr * dL_dw
            self.bias -= self.lr * dL_db
    
    def predict(self, X):
        logits = np.dot(X, self.weights) + self.bias
        probs = softmax(logits)
        return np.argmax(probs, axis=1)  

num_classes = 6
num_features = 5

model = LogisticRegression(num_features=num_features, num_classes=num_classes, lr=0.01)
model.fit(credit_scores_normalized, Y, num_classes, epochs=20000)

predictions = model.predict(credit_scores_normalized)
print("Predictions:", predictions)
accuracy = np.mean(predictions == Y)
print(f'Accuracy: {accuracy * 100:.2f}%')
# Out:
# Predictions: [1 3 3 ... 1 3 0]
# Accuracy: 46.20%

# %%
predicted_labels = [index_to_label[pred] for pred in predictions]
print(predicted_labels)
print(len(predicted_labels))
# Out:
# ['false', 'half-true', 'half-true', 'pants-fire', 'half-true', 'mostly-true', 'barely-true', 'half-true', 'half-true', 'mostly-true', 'false', 'mostly-true', 'half-true', 'mostly-true', 'barely-true', 'mostly-true', 'half-true', 'barely-true', 'false', 'false', 'false', 'barely-true', 'mostly-true', 'false', 'barely-true', 'half-true', 'mostly-true', 'half-true', 'half-true', 'mostly-true', 'mostly-true', 'barely-true', 'false', 'half-true', 'false', 'false', 'half-true', 'true', 'pants-fire', 'mostly-true', 'half-true', 'half-true', 'barely-true', 'false', 'mostly-true', 'mostly-true', 'pants-fire', 'false', 'pants-fire', 'pants-fire', 'half-true', 'barely-true', 'false', 'mostly-true', 'false', 'half-true', 'half-true', 'false', 'false', 'mostly-true', 'mostly-true', 'false', 'barely-true', 'mostly-true', 'false', 'half-true', 'half-true', 'false', 'barely-true', 'half-true', 'barely-true', 'half-true', 'mostly-true', 'mostly-true', 'half-true', 'barely-true', 'half-true', 'barely-true', 'barely-true', 'half-true', 'half-true', 'half-true', 'false', 'mostly-true', 'half-true', 'mostly-true', 'half-true', 'mostly-true', 'half-true', 'false', 'false', 'half-true', 'mostly-true', 'half-true', 'half-true', 'true', 'mostly-true', 'half-true', 'barely-true', 'mostly-true', 'false', 'pants-fire', 'half-true', 'barely-true', 'false', 'half-true', 'half-true', 'half-true', 'half-true', 'barely-true', 'false', 'barely-true', 'mostly-true', 'barely-true', 'half-true', 'half-true', 'mostly-true', 'pants-fire', 'half-true', 'false', 'mostly-true', 'mostly-true', 'mostly-true', 'barely-true', 'mostly-true', 'mostly-true', 'mostly-true', 'pants-fire', 'pants-fire', 'false', 'mostly-true', 'false', 'half-true', 'half-true', 'barely-true', 'false', 'true', 'false', 'false', 'half-true', 'half-true', 'half-true', 'false', 'mostly-true', 'half-true', 'half-true', 'half-true', 'half-true', 'false', 'false', 'half-true', 'barely-true', 'half-true', 'mostly-true', 'pants-fire', 'false', 'false', 'half-true', 'half-true', 'mostly-true', 'barely-true', 'barely-true', 'pants-fire', 'half-true', 'half-true', 'false', 'pants-fire', 'pants-fire', 'mostly-true', 'half-true', 'mostly-true', 'half-true', 'mostly-true', 'false', 'mostly-true', 'false', 'false', 'half-true', 'mostly-true', 'half-true', 'true', 'barely-true', 'half-true', 'half-true', 'barely-true', 'barely-true', 'mostly-true', 'half-true', 'barely-true', 'false', 'mostly-true', 'half-true', 'pants-fire', 'pants-fire', 'true', 'mostly-true', 'false', 'mostly-true', 'mostly-true', 'false', 'mostly-true', 'mostly-true', 'false', 'barely-true', 'false', 'barely-true', 'false', 'true', 'false', 'true', 'false', 'false', 'false', 'mostly-true', 'half-true', 'mostly-true', 'pants-fire', 'mostly-true', 'half-true', 'mostly-true', 'half-true', 'barely-true', 'half-true', 'barely-true', 'mostly-true', 'true', 'half-true', 'barely-true', 'half-true', 'half-true', 'mostly-true', 'half-true', 'false', 'mostly-true', 'half-true', 'mostly-true', 'false', 'barely-true', 'half-true', 'mostly-true', 'false', 'half-true', 'mostly-true', 'mostly-true', 'half-true', 'mostly-true', 'mostly-true', 'false', 'mostly-true', 'barely-true', 'barely-true', 'mostly-true', 'mostly-true', 'mostly-true', 'half-true', 'half-true', 'half-true', 'false', 'pants-fire', 'half-true', 'false', 'false', 'false', 'mostly-true', 'pants-fire', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'false', 'half-true', 'half-true', 'barely-true', 'false', 'false', 'half-true', 'half-true', 'false', 'half-true', 'mostly-true', 'false', 'barely-true', 'mostly-true', 'half-true', 'half-true', 'false', 'mostly-true', 'pants-fire', 'half-true', 'half-true', 'half-true', 'false', 'false', 'false', 'half-true', 'mostly-true', 'mostly-true', 'half-true', 'mostly-true', 'false', 'half-true', 'false', 'half-true', 'barely-true', 'half-true', 'half-true', 'true', 'pants-fire', 'barely-true', 'false', 'barely-true', 'half-true', 'half-t ...
# 10269

# %%
test_df= pd.read_csv(test_data_path,header=None,sep='\t',quoting=3)
test_x= test_df[2]
test_y= test_df[1]

# %%
credit_counts_test = test_df.iloc[:, 8:13].values
test_predictions = model.predict(credit_counts_test)
test_predictions = [index_to_label[pred] for pred in test_predictions]
test_accuracy = np.mean(test_predictions == test_y)
print(f'Test Accuracy: {test_accuracy * 100:.2f}%')
# Out:
# Test Accuracy: 47.82%
